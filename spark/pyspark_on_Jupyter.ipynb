# %% [markdown]
# ###  Scale horizontal

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ###  How to visualationz

# %%
import pandas as pd
import seaborn
import numpy as np;
np.random.seed(0)
import seaborn as sns;
sns.set()

# %%
uniform_data = np.random.rand(10, 12)
ax = sns.heatmap(uniform_data)

# %%
df=pd.DataFrame({'x': range(1,11), 'y1': np.random.randn(10), 'y2': np.random.randn(10)+range(1,11), 'y3': np.random.randn(10)+range(11,21) })
 
# multiple line plot
plt.plot( 'x', 'y1', data=df, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot( 'x', 'y2', data=df, marker='', color='olive', linewidth=2)
plt.plot( 'x', 'y3', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
plt.legend()
# Out:
# /home/suv/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: Second argument 'y1' is ambiguous: could be a color spec but is in data; using as data.  Either rename the entry in data or use three arguments to plot.
#   after removing the cwd from sys.path.
# /home/suv/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: Second argument 'y2' is ambiguous: could be a color spec but is in data; using as data.  Either rename the entry in data or use three arguments to plot.
#   """
# /home/suv/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: Second argument 'y3' is ambiguous: could be a color spec but is in data; using as data.  Either rename the entry in data or use three arguments to plot.

# %%
df = pd.read_excel('/home/suv/Downloads/Office/Bizda301/data_samples/Financial Sample.xlsx')

# %%
df
# Out:
#               Segment                   Country    Product Discount Band  \
# 0    Government        Canada                    Carretera  None
# 1    Government        Germany                   Carretera  None
# 2    Midmarket         France                    Carretera  None
# 3    Midmarket         Germany                   Carretera  None
# 4    Midmarket         Mexico                    Carretera  None
# 5    Government        Germany                   Carretera  None
# 6    Midmarket         Germany                   Montana    None
# 7    Channel Partners  Canada                    Montana    None
# 8    Government        France                    Montana    None
# 9    Channel Partners  Germany                   Montana    None
# 10   Midmarket         Mexico                    Montana    None
# 11   Enterprise        Canada                    Montana    None
# 12   Small Business    Mexico                    Montana    None
# ...

# %%
df2= pd.read_excel('/home/suv/Downloads/Office/Bizda301/data_samples/Ultimate Beginners Guide to DAX data file.xlsx')

# %%
list(df2)
# Out:
# ['Order ID',
#  'Product ID',
#  'Location ID',
#  'Sales Person ID',
#  'Customer ID',
#  'Purchase Date',
#  'Quantity']

# %% [markdown]
# ### Spark Type

# %%
df = spark.range(500).toDF('number')
df.select(df["number"] +10)

# %%
from pyspark.sql.types import *

# %%
b =ByteType()

# %% [markdown]
# ###  Spark SQL

# %%
spark.sql("SELECT 1 + 1").show()
# Out:
# +-------+
# |(1 + 1)|
# +-------+
# |      2|
# +-------+

# %%
spark.sql("""SELECT user_id, department, first_name FROM professors
WHERE department IN
(SELECT name FROM department WHERE created_date >= '2016-01-01')""")
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# /opt/spark/spark-2.4.4-bin-hadoop2.7/python/pyspark/sql/utils.py in deco(*a, **kw)
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#
# /opt/spark/spark-2.4.4-bin-hadoop2.7/python/lib/py4j-0.10.7-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#
# Py4JJavaError: An error occurred while calling o25.sql.
# : org.apache.spark.sql.AnalysisException: Table or view not found: professors; line 1 pos 44
# 	at org.apache.spark.sql.catalyst.analysis.package$AnalysisErrorAt.failAnalysis(package.scala:47)
# ...

# %%
--
# Out:
#   File "<ipython-input-7-28bbf89195af>", line 1
#     --
#        ^
# SyntaxError: invalid syntax

# %%
# Step 1: Create DataFrame 
# Step 2: Manipulate DataFrame
# Step 3: Read file from JSON to 
# Step 4: Parse DataFrame => SQL 
# Step 5: Saving on DB and parse SQL to DF

# %% [markdown]
# ###  Method 1

# %%
js_dir ='/home/suv/Desktop/Anaconda/data_sample/json_data/'

# %%
js_filename = 'CA_category_id.json'

# %%
js_path = js_dir + js_filename

# %%
func_readDF = spark.read.json("/home/suv/Desktop/Anaconda/data_sample/json_data/CA_category_id.json")\
.createOrReplaceTempView("some_sql_view")

# %%
func_readDF =spark.read.option("multiline", "true").json("/home/suv/Desktop/Anaconda/data_sample/json_data/CA_category_id.json")

# %%
func_readDF.printSchema()
# Out:
# root
#  |-- etag: string (nullable = true)
#  |-- items: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- etag: string (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- kind: string (nullable = true)
#  |    |    |-- snippet: struct (nullable = true)
#  |    |    |    |-- assignable: boolean (nullable = true)
#  |    |    |    |-- channelId: string (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |-- kind: string (nullable = true)

# %%
func_readDF.show()
# Out:
# +--------------------+--------------------+--------------------+
# |                etag|               items|                kind|
# +--------------------+--------------------+--------------------+
# |"ld9biNPKjAjgjV7E...|[["ld9biNPKjAjgjV...|youtube#videoCate...|
# +--------------------+--------------------+--------------------+

# %% [markdown]
# ### Method 2

# %%
readJSON = spark.read.format('json')\
                    .load('/home/suv/Desktop/Anaconda/data_sample/json_data/CA_category_id.json')

# %%
readJSON.printSchema()
# Out:
# root
#  |-- _corrupt_record: string (nullable = true)

# %% [markdown]
# ###  Method 3 import lib

# %%
from pyspark.sql import SQLContext
sqlContext = SQLContext(sc)

# %%
dfJSON = sqlContext.read.json("/home/suv/Desktop/Anaconda/data_sample/json_data/CA_category_id.json")

# %%
dfJSON.printSchema()
# Out:
# root
#  |-- _corrupt_record: string (nullable = true)

# %% [markdown]
# ###  Method 4

# %%
dfs = spark.read.json(js_path, multiLine=True)

# %%
dfs.printSchema()
# Out:
# root
#  |-- etag: string (nullable = true)
#  |-- items: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- etag: string (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- kind: string (nullable = true)
#  |    |    |-- snippet: struct (nullable = true)
#  |    |    |    |-- assignable: boolean (nullable = true)
#  |    |    |    |-- channelId: string (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |-- kind: string (nullable = true)

# %%
dfs.show()
# Out:
# +--------------------+--------------------+--------------------+
# |                etag|               items|                kind|
# +--------------------+--------------------+--------------------+
# |"ld9biNPKjAjgjV7E...|[["ld9biNPKjAjgjV...|youtube#videoCate...|
# +--------------------+--------------------+--------------------+

# %%
df = dfs.select('etag').collect()

# %%
df
# Out:
# [Row(etag='"ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2qTj13hkQZk"')]

# %%
dfs.count()
# Out:
# 1

# %%
dfs.describe()
# Out:
# DataFrame[summary: string, etag: string, kind: string]

# %%
list(dfs)
# Out:
# [Column<b'etag'>, Column<b'items'>, Column<b'kind'>]

# %% [markdown]
# ### Method 5

# %%
js_filename5='GB_category_id.json'

# %%
js_path5 = js_dir + js_filename5

# %%
js_path5
# Out:
# '/home/suv/Desktop/Anaconda/data_sample/json_data/GB_category_id.json'

# %%
dfs5 = sqlContext.read.json(sc.parallelize(js_path5))

# %%
dfs5.printSchema()
# Out:
# root
#  |-- _corrupt_record: string (nullable = true)

# %%
dfs5.show()
# Out:
# +---------------+
# |_corrupt_record|
# +---------------+
# |              /|
# |              h|
# |              o|
# |              m|
# |              e|
# |              /|
# |              s|
# |              u|
# |              v|
# |              /|
# |              D|
# |              e|
# |              s|
# |              k|
# |              t|
# |              o|
# |              p|
# |              /|
# |              A|
# |              n|
# +---------------+
# only showing top 20 rows

# %%
dfs5.select()
# Out:
# DataFrame[]

# %% [markdown]
# ###  Read Options Json

# %%
df = spark.read.option('multiline', "true").json(js_path5)

# %%
df.printSchema()
# Out:
# root
#  |-- etag: string (nullable = true)
#  |-- items: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- etag: string (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- kind: string (nullable = true)
#  |    |    |-- snippet: struct (nullable = true)
#  |    |    |    |-- assignable: boolean (nullable = true)
#  |    |    |    |-- channelId: string (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |-- kind: string (nullable = true)

# %%
df.show()
# Out:
# +--------------------+--------------------+--------------------+
# |                etag|               items|                kind|
# +--------------------+--------------------+--------------------+
# |"m2yskBQFythfE4ir...|[["m2yskBQFythfE4...|youtube#videoCate...|
# +--------------------+--------------------+--------------------+

# %%
list(df)
# Out:
# [Column<b'etag'>, Column<b'items'>, Column<b'kind'>]

# %%
import pandas as pd

# %%
df1 = df.toPandas()

# %%
df1.head(10)
# Out:
#                                                 etag  \
# 0  "m2yskBQFythfE4irbTIeOgYYfBU/1v2mrzYSYG6onNLt2...
#
#                                                items  \
# 0  [("m2yskBQFythfE4irbTIeOgYYfBU/Xy1mB4_yLrHy_Bm...
#
#                                 kind
# 0  youtube#videoCategoryListResponse

# %%
df1.etag
# Out:
# 0    "m2yskBQFythfE4irbTIeOgYYfBU/1v2mrzYSYG6onNLt2...
# Name: etag, dtype: object

# %%
#  Step 1: Define table Schema
#  Step 2: create spark session 
#  Step 3: create dataFrame

# %%
from pyspark.sql.types import ArrayType, StructField, StructType, StringType, IntegerType
schema = StructType([
    StructField('etag', StringType(), True),
    StructField('items', StringType(), True),
    StructField('kind', StringType(), True)
])

# %%
df = spark.read.json(js_path5, schema, multiLine=True)

# %%
print(df.schema)
# Out:
# StructType(List(StructField(etag,StringType,true),StructField(items,StringType,true),StructField(kind,StringType,true)))

# %%
df.show()
# Out:
# +--------------------+--------------------+--------------------+
# |                etag|               items|                kind|
# +--------------------+--------------------+--------------------+
# |"m2yskBQFythfE4ir...|[{"kind":"youtube...|youtube#videoCate...|
# +--------------------+--------------------+--------------------+

# %%
df.count()
# Out:
# 1

# %%
df.toDF()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# /opt/spark/spark-2.4.4-bin-hadoop2.7/python/pyspark/sql/utils.py in deco(*a, **kw)
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#
# /opt/spark/spark-2.4.4-bin-hadoop2.7/python/lib/py4j-0.10.7-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#
# Py4JJavaError: An error occurred while calling o301.toDF.
# : java.lang.IllegalArgumentException: requirement failed: The number of columns doesn't match.
# Old column names (3): etag, items, kind
# New column names (0):
# 	at scala.Predef$.require(Predef.scala:224)
# ...

# %%
data = []
with open(js_path5,'r') as datafile:
  for line in datafile:
    data.append(json.loads(line))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-94-a6e16f23a8f7> in <module>
#       2 with open(js_path5,'r') as datafile:
#       3   for line in datafile:
# ----> 4     data.append(json.loads(line))
#
# ~/anaconda3/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~/anaconda3/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
# ...
